# %%
import random

class board :
    def __init__(self,dim_size,num_bombs):
        self.dim_size = dim_size     # board size
        self.num_bombs = num_bombs   # number of bombs
        self.board = self.make_new_board()
        self.dug = ()                #dig status
        #helper function!
  
        
    def make_new_board(self):
                
        board = [[None]*self.dim_size for _ in range(self.dim_size)]

        bombs_planted = 0 
        while bombs_planted < self.num_bombs:   # loop until the bombs planted is less than number of bombs
            loc = random.randint(0, self.dim_size**2 -1) #random number generation
            row = loc // self.dim_size                  #whole number of the division
            col = loc % self.dim_size                   #reminder of the division
            print(f"{loc} {row} {col}")
            if board [row] [col] == '*': # bomb is already placed
                continue
            else:
                board [row] [col] == '*'
                bombs_planted +=1
                print(f"print bombs planted {bombs_planted}")
        return (board)
    def assign_values_to_board(self)
            for r in range(self.dim_size)
                for c in range(self.dim_size)
                    if self.board [r] [c] == '*'
                        continue
                    self.board [r] [c] = self.get_num_neigbhoring_bombs(r,c)
    
    def get_num_neighboring_bombs(self ,r,c):
         
         self.r = r
         self.c = c
         n = self.dim_size

             
 
            # Check up  
                if r > 0 and self.board[r-1][c] == -1:
                    self.board[r][c] = self.board[r][c] + 1
            # Check down    
                if r < n-1  and self.board[r+1][c] == -1:
                    self.board[r][c] = self.board[r][c] + 1
            # Check left
                if c > 0 and self.board[r][c-1] == -1:
                    self.board[r][c] = self.board[r][c] + 1
            # Check right
                if c < n-1 and self.board[r][c+1] == -1:
                    self.board[r][c] = self.board[r][c] + 1
            # Check top-left    
                if r > 0 and c > 0 and self.board[r-1][c-1] == -1:
                    self.board[r][c] = self.board[r][c] + 1
            # Check top-right
                if r > 0 and c < n-1 and self.board[r-1][c+1]== -1:
                    self.board[r][c] = self.board[r][c] + 1
            # Check below-left  
                if r < n-1 and c > 0 and self.board[r+1][c-1]== -1:
                    self.board[r][c] = self.board[r][c] + 1
            # Check below-right
                if r < n-1 and c< n-1 and self.board[r+1][c+1]==-1:
                    self.board[r][c] = self.board[r][c] + 1
          
        
        

x = int(input(f"Please enter the dimension"))
y = int(input(f"Please enter the number of bombs"))

new_board = board(x,y)

for newboard in new_board   :
    print(newboard)
# Out:
# 59 5 9
# print bombs planted 1
# 1 0 1
# print bombs planted 2
# 41 4 1
# print bombs planted 3
# 86 8 6
# print bombs planted 4
# 75 7 5
# print bombs planted 5
# 87 8 7
# print bombs planted 6
# 28 2 8
# print bombs planted 7
# 74 7 4
# print bombs planted 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 39
#      35 y = int(input(f"Please enter the number of bombs"))
#      37 new_board = board(x,y)
# ---> 39 for newboard in new_board   :
#      40     print(newboard)
#
# TypeError: 'board' object is not iterable
